# %%
import numpy as np
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
xy=loadtxt("tanul.dat")
n=len(xy)

x=ones((n,3))
x[:,1:]=xy[:,:2]
y=xy[:,2]

# %%
figsize(6,6)
plot(x[y==1,1],x[y==1,2],"r.",ms=4)
plot(x[y==0,1],x[y==0,2],"k.",ms=4)

# %%
Jgrid = loadtxt("Jgrid.dat")
print(len(Jgrid))
m = 76
a0mesh = resize(Jgrid[:,0],(m,m))
a1mesh = resize(Jgrid[:,1],(m,m))
Jmesh = resize(Jgrid[:,2],(m,m))
figsize(16,4)
cs = contour(a0mesh,a1mesh,Jmesh,levels=66)
clabel(cs);
# Out:
# 5700

# %%
Jgrid0 = loadtxt("Jgrid0.dat")
print(len(Jgrid0))
m = 76
a0mesh = resize(Jgrid0[:,0],(m,m))
a1mesh = resize(Jgrid0[:,1],(m,m))
Jmesh = resize(Jgrid0[:,2],(m,m))
figsize(16,4)
cs = contour(a0mesh,a1mesh,Jmesh,levels=66)
clabel(cs);
# Out:
# 5776

# %%
deriv = loadtxt("deriv.dat")
m = 101
print(len(deriv))
a0mesh = resize(deriv[:,0],(m,m))
a1mesh = resize(deriv[:,1],(m,m))
derivmesh = resize(deriv[:,2],(m,m))
figsize(16,4)
cs = contour(a0mesh,a1mesh,derivmesh,levels=66)
clabel(cs);
# Out:
# 10201

# %%
plot(deriv[:,2][-100:-1])
deriv[:,0],deriv[:,2]
# Out:
# (array([-14.98996 , -14.993727, -14.996085, ..., -14.195442, -14.195368,
#         -14.195295]),
#  array([1.806583, 0.628778, 0.282167, ..., 0.275284, 0.275283, 0.275283]))

# %%
deriv0 = loadtxt("deriv0.dat")
m = 101
a0mesh = resize(deriv0[:,0],(m,m))
a1mesh = resize(deriv0[:,1],(m,m))
deriv0mesh = resize(deriv0[:,2],(m,m))
print(len(deriv0))
figsize(16,4)
cs = contour(a0mesh,a1mesh,deriv0mesh,levels=66)
clabel(cs);
# Out:
# 10201

# %%
deriv0, deriv, len(deriv0), len(deriv)
# Out:
# (array([[-1.500000e+01,  0.000000e+00,  8.524159e+00],
#         [-1.500000e+01,  6.000000e-03,  8.216838e+00],
#         [-1.500000e+01,  1.200000e-02,  7.909519e+00],
#         ...,
#         [-5.000000e+00,  5.880000e-01,  1.000000e+00],
#         [-5.000000e+00,  5.940000e-01,  1.000000e+00],
#         [-5.000000e+00,  6.000000e-01,  1.000000e+00]]),
#  array([[-1.500000e+01,  0.000000e+00,  8.524159e+00],
#         [-1.500000e+01,  6.000000e-03,  8.290595e+00],
#         [-1.500000e+01,  1.200000e-02,  8.057032e+00],
#         ...,
#         [-5.000000e+00,  5.820000e-01,  4.657345e+00],
#         [-5.000000e+00,  5.880000e-01,  4.723262e+00],
#         [-5.000000e+00,  5.940000e-01,  4.789196e+00]]),
#  10201,
#  10100)

# %%
print(np.array(deriv0[:,0]))
# Out:
# [-15. -15. -15. ...  -5.  -5.  -5.]

# %%
Jgrid0, Jgrid, len(Jgrid0), len(Jgrid)
# Out:
# (array([[-1.500000e+01,  0.000000e+00,  1.003996e+01],
#         [-1.500000e+01,  7.895000e-03,  9.732638e+00],
#         [-1.500000e+01,  1.578900e-02,  9.425315e+00],
#         ...,
#         [-5.131579e+00,  5.763160e-01,  4.673021e+00],
#         [-5.131579e+00,  5.842110e-01,  4.759771e+00],
#         [-5.131579e+00,  5.921050e-01,  4.846537e+00]]),
#  array([[-1.500000e+01,  0.000000e+00,  1.003996e+01],
#         [-1.500000e+01,  7.895000e-03,  9.732638e+00],
#         [-1.500000e+01,  1.578900e-02,  9.425315e+00],
#         ...,
#         [-5.131579e+00,  5.763160e-01,  4.673021e+00],
#         [-5.131579e+00,  5.842110e-01,  4.759771e+00],
#         [-5.131579e+00,  5.921050e-01,  4.846537e+00]]),
#  5776,
#  5776)

# %%
#Jgrid = loadtxt("deriv_test.dat")
m = 76
a0mesh = resize(Jgrid[:,0],(m,m))
a1mesh = resize(Jgrid[:,1],(m,m))
Jmesh = resize(Jgrid[:,2],(m,m))
print(len(Jgrid[:,2]))
# Out:
# 5776

# %%
plot(Jgrid[:,0], Jgrid[:,2])
len(Jgrid[:,0])
# Out:
# 5776

# %%
Jgrid[:,2][1], Jgrid[:,2][-1]
# Out:
# (1.287254, 0.460066)

# %%
figsize(16,4)
cs = contour(a0mesh,a1mesh,Jmesh,levels=66)
clabel(cs);

# %%
deriv010 = loadtxt("deriv_010.dat")
m = 201
print(len(deriv010))
a0mesh = resize(deriv010[:,0],(m,m))
a1mesh = resize(deriv010[:,1],(m,m))
derivmesh = resize(deriv010[:,2],(m,m))
figsize(16,4)
cs = contour(a0mesh,a1mesh,derivmesh,levels=66)
clabel(cs);
# Out:
# 10201

# %%
deriv015 = loadtxt("deriv_015.dat")
m = 201
print(len(deriv015))
a0mesh = resize(deriv015[:,0],(m,m))
a1mesh = resize(deriv015[:,1],(m,m))
derivmesh = resize(deriv015[:,2],(m,m))
figsize(16,4)
cs = contour(a0mesh,a1mesh,derivmesh,levels=66)
clabel(cs);
# Out:
# 10201

# %%
deriv020 = loadtxt("deriv_020.dat")
m = 201
print(len(deriv020))
a0mesh = resize(deriv020[:,0],(m,m))
a1mesh = resize(deriv020[:,1],(m,m))
derivmesh = resize(deriv020[:,2],(m,m))
figsize(16,4)
cs = contour(a0mesh,a1mesh,derivmesh,levels=66)
clabel(cs);
# Out:
# 10201

# %%
deriv0125 = loadtxt("deriv_0125.dat")
m = 201
print(len(deriv0125))
a0mesh = resize(deriv0125[:,0],(m,m))
a1mesh = resize(deriv0125[:,1],(m,m))
derivmesh = resize(deriv0125[:,2],(m,m))
figsize(16,4)
cs = contour(a0mesh,a1mesh,derivmesh,levels=66)
clabel(cs);
# Out:
# 40401

# %%
figsize(12,12)
plt.plot(deriv010[:,2][-100:-1], label = " $\\alpha=0.010$ ", color = "r")
plt.plot(deriv015[:,2][-100:-1], label = " $\\alpha=0.015$ ", color = "g")
plt.plot(deriv020[:,2][-100:-1], label = " $\\alpha=0.020$ ", color = "b")
plt.plot(deriv0125[:,2][-100:-1], label = " $\\alpha=0.0125$ ", color = "black")
plt.legend()
plt.show()

# %%
Jgrid2_init = loadtxt("Jgrid2_init.dat")
print(len(Jgrid2_init))
m = 76
a0mesh = resize(Jgrid2_init[:,0],(m,m))
a1mesh = resize(Jgrid2_init[:,1],(m,m))
Jmesh = resize(Jgrid2_init[:,2],(m,m))
figsize(16,4)
cs = contour(a0mesh,a1mesh,Jmesh,levels=66)
clabel(cs);
# Out:
# 5775

# %%
Jgrid2 = loadtxt("Jgrid2.dat")
print(len(Jgrid2))
m = 76
a0mesh = resize(Jgrid2[:,0],(m,m))
a1mesh = resize(Jgrid2[:,1],(m,m))
Jmesh = resize(Jgrid2[:,2],(m,m))
figsize(16,4)
cs = contour(a0mesh,a1mesh,Jmesh,levels=66)
clabel(cs);
# Out:
# 5775
